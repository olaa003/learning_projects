# %% [markdown]
# # The Office
# In this project, we will take a look at a dataset of The Office episodes, and try to understand how
#
# 1. the popularity and
#
# 2. quality
#
# of the office series varied over time

# %%
#importing the data as a pandas dataframe
import pandas as pd
office=pd.read_csv('the_office_series.csv',index_col=0, parse_dates=['Date'])
office.describe(include='all')
# Out:
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_15716/3572507096.py:4: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   office.describe(include='all')
#             Season EpisodeTitle  \
# count   188.000000          188
# unique         NaN          188
# top            NaN        Pilot
# freq           NaN            1
# first          NaN          NaN
# last           NaN          NaN
# mean      5.468085          NaN
# std       2.386245          NaN
# min       1.000000          NaN
# 25%       3.000000          NaN
# 50%       6.000000          NaN
# 75%       7.250000          NaN
# max       9.000000          NaN
#
#                                                     About     Ratings  \
# count                                                 188  188.000000
# ...

# %% [markdown]
# ## Inspecting data
# from inspecting the table we notice that each row corresponds to an episode in the series and that there are only season numbers but no episode numbers. There are 9 seasons in total and no null values, this data is considerably clean and with a little adjustments it will be ready for deriving insight based on our objectives.

# %% [markdown]
# ### cleaning/tranforming

# %%
office.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 188 entries, 0 to 187
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Season        188 non-null    int64
#  1   EpisodeTitle  188 non-null    object
#  2   About         188 non-null    object
#  3   Ratings       188 non-null    float64
#  4   Votes         188 non-null    int64
#  5   Viewership    188 non-null    float64
#  6   Duration      188 non-null    int64
#  7   Date          188 non-null    datetime64[ns]
#  8   GuestStars    29 non-null     object
#  9   Director      188 non-null    object
#  10  Writers       188 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(3), object(5)
# memory usage: 17.6+ KB

# %%
# getting year out of date
import datetime as dt
office['year']=office['Date'].dt.year
office
# Out:
#      Season      EpisodeTitle  \
# 0         1             Pilot
# 1         1     Diversity Day
# 2         1       Health Care
# 3         1      The Alliance
# 4         1        Basketball
# ..      ...               ...
# 183       9     Stairmageddon
# 184       9    Paper Airplane
# 185       9  Livin' the Dream
# 186       9          A.A.R.M.
# 187       9            Finale
#
#                                                  About  Ratings  Votes  \
# 0    The premiere episode introduces the boss and s...      7.5   4936
# 1    Michael's off color remark puts a sensitivity ...      8.3   4801
# 2    Michael leaves Dwight in charge of picking the...      7.8   4024
# 3    Just for a laugh, Jim agrees to an alliance wi...      8.1   3915
# 4    Michael and his staff challenge the warehouse ...      8.4   4294
# ..                                                 ...      ...    ...
# 183  Dwight shoots Stanley with a bull tranquilizer...      8.0   1985
# ...

# %% [markdown]
# ### Exploratory data analysis to see how popularity of the show varied with time

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
_=plt.plot(office['Date'],office['Viewership'])
_=plt.title('Viewership Changes over Time')
_=plt.ylabel('Viewership In Millions')
plt.show()

# %%
office[office['Viewership']==office['Viewership'].max()]
# Out:
#     Season   EpisodeTitle                                              About  \
# 77       5  Stress Relief  Dwight's too-realistic fire alarm gives Stanle...
#
#     Ratings  Votes  Viewership  Duration       Date  \
# 77      9.7   8170       22.91        60 2009-02-01
#
#                                    GuestStars       Director  \
# 77  Cloris Leachman, Jack Black, Jessica Alba  Jeffrey Blitz
#
#              Writers  year
# 77  Paul Lieberstein  2009

# %%
office[office['Viewership']==office['Viewership'].min()]
# Out:
#      Season    EpisodeTitle  \
# 184       9  Paper Airplane
#
#                                                  About  Ratings  Votes  \
# 184  The employees hold a paper airplane competitio...      8.0   2007
#
#      Viewership  Duration       Date GuestStars      Director  \
# 184        3.25        22 2013-04-25        NaN  Jesse Peretz
#
#                                    Writers  year
# 184  Halsted Sullivan | Warren Lieberstein  2013

# %%
#using median as a summary statistic and grouping over the seasons.
#season 5 is in 2009 and the decline starts from there.
view_average = office.groupby('Season')['Viewership'].median()
_=plt.bar(view_average.index,view_average)
_=plt.title('Average Viewership Per Season')
_=plt.ylabel('Average Viewership In Millions')
plt.show()

# %% [markdown]
# ### Insights
#
# From the plot above, it can be observed that there as been a slow but gradual decline in the viewership of the shout, with a some flunctuations in between.
# The viewership was unusually high in an episode in 2009, and on deeper inspection it was observed that that number of views was recorded because were three guest stars present there!
#
# The first episode of the show started out averaging about 11 million views, but it maintained an average of about 8 million views till 2009 )of course with some flunctuations which may have been due to guestars or advertisement changes). From 2009 it saw a continuous decline to less than 5 million, which might have marked that it was time to end the series. For the final episode however, the viewership built up to about 5 million.

# %% [markdown]
# ### Exploratory data analysis to see how the quality of the show varied with time

# %% [markdown]
# The ratings would be the main parameter to judge the quality of the show

# %%
#examining the column of interest
office['Ratings'].describe()
# Out:
# count    188.000000
# mean       8.237234
# std        0.589930
# min        6.600000
# 25%        7.800000
# 50%        8.200000
# 75%        8.600000
# max        9.800000
# Name: Ratings, dtype: float64

# %% [markdown]
# It can be seen that the minimum rating is 6.6 and the maximum rating is 9.8.
# we can go with this or we can normalize the column to get the the differences in ratings clearer

# %%
# normalizing the column
office['Ratings']=(office['Ratings']-office['Ratings'].min())/(office['Ratings'].max()-office['Ratings'].min())
office['Ratings'].describe()
# Out:
# count    188.000000
# mean       0.511636
# std        0.184353
# min        0.000000
# 25%        0.375000
# 50%        0.500000
# 75%        0.625000
# max        1.000000
# Name: Ratings, dtype: float64

# %%
plt.figure(figsize=(10,6))
_=plt.plot(office['Date'],office['Ratings'])
_=plt.title('Ratings Changes over Time')
_=plt.ylabel('Normalized Ratings')
plt.show()

# %%
rating_average = office.groupby('Season')['Ratings'].median()
_=plt.bar(rating_average.index,rating_average)
_=plt.title('Average Ratings Per Season')
_=plt.ylabel('Average Ratings')
plt.show()

# %% [markdown]
# # Insight
#
# The rating follows a trend similar to that of the viewership, The ratings peak between 2007 and 2008 and becomes really low
# between 2011 and 2013 at the latter seasons.

# %% [markdown]
# ## Conclusion
#
# Both the ratings and viewership have shown a gradual downward trend and it might have been the best decision to end the series or revamp and restrategize
